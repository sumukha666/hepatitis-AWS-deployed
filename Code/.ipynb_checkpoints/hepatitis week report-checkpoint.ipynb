# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV

from sklearn.metrics import roc_curve, auc, accuracy_score
from sklearn.metrics import precision_recall_curve, confusion_matrix

from sklearn.preprocessing import Imputer

# %%
df = pd.read_csv("../HCV-Egy-Data.csv")
df.head()
# Out:
#    Age   Gender  BMI  Fever  Nausea/Vomting  Headache   Diarrhea   \
# 0    56       1   35      2               1          1          1
# 1    46       1   29      1               2          2          1
# 2    57       1   33      2               2          2          2
# 3    49       2   33      1               2          1          2
# 4    59       1   32      1               1          2          1
#
#    Fatigue & generalized bone ache   Jaundice   Epigastric pain   ...  ALT 36  \
# 0                                 2          2                 2  ...       5
# 1                                 2          2                 1  ...      57
# 2                                 1          1                 1  ...       5
# 3                                 1          2                 1  ...      48
# 4                                 2          2                 2  ...      94
#
#    ALT 48  ALT after 24 w  RNA Base   RNA 4   RNA 12  RNA EOT  RNA EF  \
# 0       5               5    655330  634536   288194        5       5
# 1     123              44     40620  538635   637056   336804   31085
# 2       5               5    571148  661346        5   735945  558829
# 3      77              33   1041941  449939   585688   744463  582301
# 4      90              30    660410  738756  3731527   338946  242861
#
#    Baseline histological Grading  Baselinehistological staging
# 0                             13                             2
# 1                              4                             2
# 2                              4                             4
# 3                             10                             3
# 4                             11                             1
#
# [5 rows x 29 columns]

# %%
features = list(df.columns)
#exclude_list = ['Baselinehistological staging','WBC','RBC','HGB','Plat','ALT 48','ALT after 24 w','RNA Base','RNA 4','RNA 12','RNA EOT','RNA EF','Baseline histological Grading','Age','Gender','BMI','Fever','Nausea/Vomting','Headache','Diarrhea','Fatigue & generalized bone ache','Jaundice','Epigastric pain Epigastric pain']
#print features
exclude_list = ['Baselinehistological staging','Age ','Gender','BMI','Fever','Nausea/Vomting','Headache ' ,'Diarrhea ','Fatigue & generalized bone ache ','Jaundice ' ,'Epigastric pain ', 'WBC','RBC','HGB','Plat','ALT 48','ALT after 24 w','RNA Base','RNA 4','RNA 12','RNA EOT','RNA EF','Baseline histological Grading','AST 1','ALT 48']
for i in exclude_list:
    #print i
    features.remove(i)

    
X = df[features]
y = df['ALT 36'] 


#weeks = list('ALT 1','ALT4','ALT 12','ALT 24','ALT 36')
#X= df[weeks]
print X.head
print y.size
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-d4d7337f35a6> in <module>()
#       5 for i in exclude_list:
#       6     #print i
# ----> 7     features.remove(i)
#       8
#       9
#
# ValueError: list.remove(x): x not in list

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
# logistic regression
from sklearn.linear_model import LogisticRegression 

classifier = LogisticRegression(random_state = 0) 

classifier.fit(X_train, y_train) 

y_pred = classifier.predict(X_test) 

print ("Accuracy : ", metrics.accuracy_score(y_test, y_pred))
# Out:
# ('Accuracy : ', 1.083032490974729)
